# %% [markdown]
# # Streamlit prep
#
# In this notebook we'll do some basic setup to create the correct data for our streamlit app to work.
#
# I'll revise this as needed, but currently we only need the top 10k songs to work with the model.

# %%
# imports
import pandas as pd

from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
# get top 1M songs
song_listens = pd.read_csv('/drive/My Drive/Colab Notebooks/top_songs.csv')
song_listens.drop(columns=['Unnamed: 0'], inplace=True)

# %%
song_listens.head()
# Out:
#    song_no  listen_no
# 0     5538       2657
# 1    11453       2440
# 2     1200       2355
# 3     3026       2296
# 4     1071       2292

# %%
len(song_listens)
# Out:
# 1000000

# %%
# reduce to top 10k songs
song_listens = song_listens.iloc[:10000]
len(song_listens)
# Out:
# 10000

# %%
# create list of song_listens
song_listens_list = song_listens['song_no'].tolist()
song_listens_list[:5]
# Out:
# [5538, 11453, 1200, 3026, 1071]

# %%
song_id = pd.read_csv('/drive/My Drive/Colab Notebooks/song_table.csv')
song_id.drop(columns=['Unnamed: 0'], inplace=True)

# %%
song_id.head()
# Out:
#                   artist_name                      track_name  song_no
# 0          Katy B X Mr. Mitch                           Heavy        0
# 1          These Hidden Hands                         SZ31X71        1
# 2         Esben and the Witch  Marking the Heart of a Serpent        2
# 3  death's dynamic shroud.wmv                  Loving Is Easy        3
# 4                        Fuzz              What's In My Head?        4

# %%
# filter song_id to only include songs from the top 10k songs
song_id = song_id[song_id['song_no'].isin(song_listens_list)]

# %%
len(song_id)
# Out:
# 10000

# %%
# save these songs for use in streamlit
song_id.to_csv('/drive/My Drive/Colab Notebooks/song_table10k.csv')
